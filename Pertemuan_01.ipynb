# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanji14-byte/Pemograman-Dasar/blob/main/Pertemuan_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Vanji"
NIM = 4232511055
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
status_lulus = False

print (nama)
print (NIM)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Vanji
# 4232511055
# 20
# RPE
# 3
# Pemerograman Dasar
# False
