# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanji14-byte/Pemograman-Dasar/blob/main/Pertemuan_o2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Latihan 1
tegangan = 18                  # int
arus = 6.5                     # float
jenis_sel = "Monocrystalline"  # str

print(tegangan, arus, jenis_sel)
# Out:
# 18 6.5 Monocrystalline

# %%
# Latihan 2
# Spesifikasi Relay Timer
Limit_Voltage = 240
Jenis_Timer = "Relay Timer"
Limit_Current = 9.5
Using_3phase = False

print(Limit_Voltage)
print(Jenis_Timer)
print(Limit_Current)
print(Using_3phase)
# Out:
# 240
# Relay Timer
# 9.5
# False

# %%
# Latihan 3
NamaUnit = "PLTS Nunukan"
JumlahPanel = 240
TeganganKeluaran = 48.5
SedangBeroperasi = True

print (NamaUnit, JumlahPanel, TeganganKeluaran, SedangBeroperasi)
# Out:
# PLTS Nunukan 240 48.5 True

# %%
# Latihan 4
arus_harian = [6.2, 8.4, 9.4, 11,1, 14.6]
suhu_harian.append(15.3)

print("Setelah ditambah:", arus_harian)
print("Suhu jam ke-3:", arus_harian[2])
# Out:
# Setelah ditambah: [6.2, 8.4, 9.4, 11, 1, 14.6]
# Suhu jam ke-3: 9.4

# %%
# Latihan 5

exhaust_fan = {
    "nama": "unit-5",
    "kapasitas_MW" : 750,
    "kapasitas_kV": 50,
    "status": "repairing"
}

print("kapasitas_MW:", exhaust_fan["kapasitas_MW"], "MW")
exhaust_fan["status"] = "monitoring after repairing"
print(exhaust_fan)
# Out:
# kapasitas_MW: 750 MW
# {'nama': 'unit-5', 'kapasitas_MW': 750, 'kapasitas_kV': 50, 'status': 'monitoring after repairing'}

# %%
# Latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"},
]

print("Nama unit kedua:", pembangkit[1]["nama"])
pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 200, "status": "operasi"})
print("\nSeluruh Data Pembangkit saat ini:")
for unit in pembangkit:
    print(unit)
# Out:
# Nama unit kedua: Unit-2
#
# Seluruh Data Pembangkit saat ini:
# {'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}
# {'nama': 'Unit-4', 'kapasitas_MW': 200, 'status': 'operasi'}
